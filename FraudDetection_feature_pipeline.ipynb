# %% [markdown]
# <a href="https://colab.research.google.com/github/canterville184/FraudDetection/blob/main/FraudDetection_feature_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U 'hopsworks[python]' --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 90.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.6/258.6 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 56.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 88.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.4/646.4 kB 40.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 93.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.6 MB/s eta 0:00:00
#   Building wheel for avro (pyproject.toml) ... done
#   Building wheel for twofish (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-36.1.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.1)
# Downloading Faker-36.1.1-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.4 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-36.1.1

# %%
import pandas as pd
import os
import numpy as np
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_data = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/ML_portfolio/FraudDetection/synthetic_financial_dataset_fraud_detection.zip', 'r')
data = pd.read_csv(zip_data.open('PS_20174392719_1491204439457_log.csv'))

# %%
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %% [markdown]
# # Feature Engineering

# %%
from datetime import timedelta
import random

def random_date(start, end):
    """
    This function will return a random datetime between two datetime
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = random.randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
from datetime import datetime

d1 = datetime.strptime('1/1/2018 1:30 PM', '%m/%d/%Y %I:%M %p')
d2 = datetime.strptime('1/1/2019 4:50 AM', '%m/%d/%Y %I:%M %p')

print(random_date(d1, d2))
# Out:
# 2018-01-29 05:10:28

# %%
# Set a date for the transaction based on step
x_date = random_date(d1, d2)
data['date'] = [x_date + pd.DateOffset(hours=x) for x in data['step']]

# %%
# Set a transaction_id
data.index = np.arange(1, len(data) + 1)
data['transaction_id'] = data.index

# %%
from faker import Faker

# Initialize the Faker generator
fake = Faker()

data['state'] = [fake.state_abbr() for _ in range(len(data))]
data['zipcode'] = [fake.zipcode_in_state(state) for state in data['state']]
data['ipv4'] = [fake.ipv4() for _ in range(len(data))]
data['mac_address'] = [fake.mac_address() for _ in range(len(data))]

# %%
data.head()

# %% [markdown]
# # Customer Profile Information
# - Customer Account Age: Helps assess risk based on account longevity.
# - Transaction Frequency: Number of transactions per customer over different time windows (hourly, daily, weekly, etc.).
# - Historical Fraud Flag: Has the customer been involved in past fraudulent activity?

# %%
data.columns

# %% [markdown]
# # Creating Feature Groups in Feature Store

# %%
customer_list = list(set(list(data['nameOrig'].unique()) + list(data['nameDest'].unique())))

# %%
data['isFraud'].value_counts()

# %%
import random


sampleList = [0, 1]

randomList = random.choices(
  sampleList, weights=(70, 30), k=1)

print(randomList)
# Out:
# [0]

# %%
import random

max_account_age = 120
limit = 20

customer_ds = pd.DataFrame()
cust_id = 1
for customer in customer_list:
  trans_cust = data[(data['nameOrig'] == customer) | (data['nameDest'] == customer)]
  days_diff = trans_cust['date'].max() - trans_cust['date'].max()
  days_diff = days_diff.days
  total_trans = trans_cust.shape[0]
  total_fraud_trans = trans_cust[trans_cust['isFraud']==1].shape[0]
  trans_per_day = int(round(total_trans/days_diff, 0))
  isfraud_rand = random.choices([0, 1], weights=(25, 75), k=1)[0] if total_fraud_trans > 1 else random.choices([0, 1], weights=(75, 25), k=1)[0]
  account_age =  random.randint(0, limit) if isfraud_rand == 1 else random.randint(limit, max_account_age)
  customer_ds.loc[cust_id, 'customer_id'] = customer
  customer_ds.loc[cust_id, 'name'] = faker.name()
  customer_ds.loc[cust_id, 'dob'] = faker.date()
  customer_ds.loc[cust_id, 'account_age'] = account_age
  customer_ds.loc[cust_id, 'total_trans'] = total_trans
  customer_ds.loc[cust_id, 'trans_per_day'] = trans_per_day
  customer_ds.loc[cust_id, 'hist_fraud_flag'] = isfraud_rand
  cust_id += 1
  print('total_trans: {}, total_fraud_trans: {}, account_age: {}, days_diff: {}, trans_per_day: {}'.format(total_trans, total_fraud_trans, account_age, days_diff, trans_per_day))
# Out:
# total_trans: 1, total_fraud_trans: 0, account_age: 24
# total_trans: 1, total_fraud_trans: 0, account_age: 120
# total_trans: 1, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 105
# total_trans: 1, total_fraud_trans: 0, account_age: 87
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 95
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 71
# total_trans: 5, total_fraud_trans: 0, account_age: 77
# total_trans: 14, total_fraud_trans: 0, account_age: 29
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 89
# total_trans: 1, total_fraud_trans: 0, account_age: 64
# total_trans: 1, total_fraud_trans: 0, account_age: 112
# total_trans: 5, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 1, total_fraud_trans: 0, account_age: 76
# total_trans: 1, total_fraud_trans: 0, account_age: 81
# total_trans: 1, total_fraud_trans: 0, account_age: 79
# total_trans: 1, total_fraud_trans: 0, account_age: 52
# total_trans: 1, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 50
# total_trans: 1, total_fraud_trans: 0, account_age: 26
# total_trans: 1, total_fraud_trans: 0, account_age: 56
# total_trans: 1, total_fraud_trans: 0, account_age: 76
# total_trans: 1, total_fraud_trans: 0, account_age: 59
# total_trans: 3, total_fraud_trans: 0, account_age: 36
# total_trans: 1, total_fraud_trans: 0, account_age: 76
# total_trans: 1, total_fraud_trans: 0, account_age: 23
# total_trans: 1, total_fraud_trans: 0, account_age: 27
# total_trans: 1, total_fraud_trans: 0, account_age: 43
# total_trans: 1, total_fraud_trans: 0, account_age: 70
# total_trans: 1, total_fraud_trans: 0, account_age: 32
# total_trans: 1, total_fraud_trans: 0, account_age: 71
# total_trans: 1, total_fraud_trans: 0, account_age: 80
# total_trans: 1, total_fraud_trans: 0, account_age: 40
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 43
# total_trans: 14, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 26
# total_trans: 1, total_fraud_trans: 0, account_age: 52
# total_trans: 1, total_fraud_trans: 0, account_age: 50
# total_trans: 1, total_fraud_trans: 0, account_age: 81
# total_trans: 3, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 49
# total_trans: 1, total_fraud_trans: 0, account_age: 66
# total_trans: 1, total_fraud_trans: 0, account_age: 113
# total_trans: 1, total_fraud_trans: 0, account_age: 107
# total_trans: 1, total_fraud_trans: 0, account_age: 69
# total_trans: 16, total_fraud_trans: 0, account_age: 36
# total_trans: 1, total_fraud_trans: 0, account_age: 24
# total_trans: 1, total_fraud_trans: 0, account_age: 118
# total_trans: 1, total_fraud_trans: 0, account_age: 88
# total_trans: 1, total_fraud_trans: 0, account_age: 90
# total_trans: 1, total_fraud_trans: 0, account_age: 21
# total_trans: 1, total_fraud_trans: 0, account_age: 88
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 1, total_fraud_trans: 0, account_age: 46
# total_trans: 1, total_fraud_trans: 0, account_age: 61
# total_trans: 1, total_fraud_trans: 0, account_age: 116
# total_trans: 1, total_fraud_trans: 0, account_age: 38
# total_trans: 1, total_fraud_trans: 0, account_age: 30
# total_trans: 1, total_fraud_trans: 0, account_age: 31
# total_trans: 1, total_fraud_trans: 0, account_age: 23
# total_trans: 1, total_fraud_trans: 0, account_age: 45
# total_trans: 1, total_fraud_trans: 0, account_age: 98
# total_trans: 1, total_fraud_trans: 0, account_age: 114
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 7, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 90
# total_trans: 1, total_fraud_trans: 0, account_age: 31
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 64
# total_trans: 1, total_fraud_trans: 0, account_age: 85
# total_trans: 1, total_fraud_trans: 0, account_age: 34
# total_trans: 1, total_fraud_trans: 0, account_age: 74
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 22
# total_trans: 1, total_fraud_trans: 0, account_age: 104
# total_trans: 1, total_fraud_trans: 0, account_age: 54
# total_trans: 20, total_fraud_trans: 0, account_age: 84
# total_trans: 1, total_fraud_trans: 0, account_age: 83
# total_trans: 1, total_fraud_trans: 0, account_age: 24
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 31
# total_trans: 14, total_fraud_trans: 0, account_age: 69
# total_trans: 1, total_fraud_trans: 0, account_age: 40
# total_trans: 1, total_fraud_trans: 0, account_age: 46
# total_trans: 1, total_fraud_trans: 0, account_age: 28
# total_trans: 1, total_fraud_trans: 0, account_age: 44
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 70
# total_trans: 1, total_fraud_trans: 0, account_age: 92
# total_trans: 1, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 103
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 1, total_fraud_trans: 0, account_age: 91
# total_trans: 1, total_fraud_trans: 0, account_age: 65
# total_trans: 3, total_fraud_trans: 0, account_age: 34
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 1, total_fraud_trans: 0, account_age: 81
# total_trans: 1, total_fraud_trans: 0, account_age: 101
# total_trans: 1, total_fraud_trans: 0, account_age: 42
# total_trans: 1, total_fraud_trans: 0, account_age: 82
# total_trans: 1, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 57
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 48
# total_trans: 1, total_fraud_trans: 0, account_age: 44
# total_trans: 1, total_fraud_trans: 0, account_age: 98
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 98
# total_trans: 1, total_fraud_trans: 0, account_age: 95
# total_trans: 1, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 61
# total_trans: 5, total_fraud_trans: 0, account_age: 82
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 95
# total_trans: 1, total_fraud_trans: 0, account_age: 79
# total_trans: 1, total_fraud_trans: 0, account_age: 87
# total_trans: 4, total_fraud_trans: 0, account_age: 26
# total_trans: 1, total_fraud_trans: 0, account_age: 87
# total_trans: 1, total_fraud_trans: 0, account_age: 110
# total_trans: 1, total_fraud_trans: 0, account_age: 83
# total_trans: 1, total_fraud_trans: 0, account_age: 65
# total_trans: 1, total_fraud_trans: 0, account_age: 39
# total_trans: 1, total_fraud_trans: 0, account_age: 83
# total_trans: 1, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 118
# total_trans: 2, total_fraud_trans: 0, account_age: 65
# total_trans: 11, total_fraud_trans: 0, account_age: 86
# total_trans: 1, total_fraud_trans: 0, account_age: 114
# total_trans: 1, total_fraud_trans: 0, account_age: 83
# total_trans: 1, total_fraud_trans: 0, account_age: 37
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 90
# total_trans: 1, total_fraud_trans: 0, account_age: 69
# total_trans: 1, total_fraud_trans: 0, account_age: 94
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 29
# total_trans: 1, total_fraud_trans: 0, account_age: 66
# total_trans: 1, total_fraud_trans: 0, account_age: 97
# total_trans: 1, total_fraud_trans: 0, account_age: 28
# total_trans: 1, total_fraud_trans: 0, account_age: 35
# total_trans: 1, total_fraud_trans: 0, account_age: 28
# total_trans: 1, total_fraud_trans: 0, account_age: 107
# total_trans: 1, total_fraud_trans: 0, account_age: 83
# total_trans: 1, total_fraud_trans: 0, account_age: 97
# total_trans: 1, total_fraud_trans: 0, account_age: 105
# total_trans: 13, total_fraud_trans: 0, account_age: 64
# total_trans: 1, total_fraud_trans: 0, account_age: 36
# total_trans: 1, total_fraud_trans: 0, account_age: 47
# total_trans: 1, total_fraud_trans: 0, account_age: 99
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 84
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 21
# total_trans: 1, total_fraud_trans: 0, account_age: 102
# total_trans: 1, total_fraud_trans: 0, account_age: 109
# total_trans: 1, total_fraud_trans: 0, account_age: 99
# total_trans: 1, total_fraud_trans: 0, account_age: 80
# total_trans: 1, total_fraud_trans: 0, account_age: 113
# total_trans: 1, total_fraud_trans: 0, account_age: 96
# total_trans: 1, total_fraud_trans: 0, account_age: 108
# total_trans: 1, total_fraud_trans: 0, account_age: 57
# total_trans: 1, total_fraud_trans: 0, account_age: 29
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 46
# total_trans: 1, total_fraud_trans: 0, account_age: 82
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 41
# total_trans: 1, total_fraud_trans: 0, account_age: 25
# total_trans: 1, total_fraud_trans: 0, account_age: 105
# total_trans: 1, total_fraud_trans: 0, account_age: 52
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 24
# total_trans: 1, total_fraud_trans: 0, account_age: 47
# total_trans: 1, total_fraud_trans: 0, account_age: 92
# total_trans: 1, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 50
# total_trans: 1, total_fraud_trans: 0, account_age: 85
# total_trans: 1, total_fraud_trans: 0, account_age: 36
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 53
# total_trans: 1, total_fraud_trans: 0, account_age: 88
# total_trans: 1, total_fraud_trans: 0, account_age: 82
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 84
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 54
# total_trans: 1, total_fraud_trans: 0, account_age: 98
# total_trans: 1, total_fraud_trans: 0, account_age: 27
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 1, total_fraud_trans: 0, account_age: 59
# total_trans: 1, total_fraud_trans: 0, account_age: 50
# total_trans: 1, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 58
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 45
# total_trans: 1, total_fraud_trans: 0, account_age: 34
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 38
# total_trans: 1, total_fraud_trans: 0, account_age: 54
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 105
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 2, total_fraud_trans: 0, account_age: 58
# total_trans: 1, total_fraud_trans: 0, account_age: 40
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 91
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 32
# total_trans: 1, total_fraud_trans: 0, account_age: 44
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 1, total_fraud_trans: 0, account_age: 47
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 69
# total_trans: 1, total_fraud_trans: 0, account_age: 75
# total_trans: 1, total_fraud_trans: 0, account_age: 46
# total_trans: 1, total_fraud_trans: 0, account_age: 120
# total_trans: 1, total_fraud_trans: 0, account_age: 100
# total_trans: 1, total_fraud_trans: 0, account_age: 54
# total_trans: 1, total_fraud_trans: 0, account_age: 36
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 86
# total_trans: 1, total_fraud_trans: 0, account_age: 74
# total_trans: 1, total_fraud_trans: 0, account_age: 38
# total_trans: 1, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 108
# total_trans: 1, total_fraud_trans: 0, account_age: 76
# total_trans: 1, total_fraud_trans: 0, account_age: 25
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 62
# total_trans: 4, total_fraud_trans: 0, account_age: 101
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 53
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 72
# total_trans: 1, total_fraud_trans: 0, account_age: 25
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 109
# total_trans: 1, total_fraud_trans: 0, account_age: 120
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 47
# total_trans: 1, total_fraud_trans: 0, account_age: 65
# total_trans: 1, total_fraud_trans: 0, account_age: 107
# total_trans: 1, total_fraud_trans: 0, account_age: 20
# total_trans: 3, total_fraud_trans: 0, account_age: 68
# total_trans: 1, total_fraud_trans: 0, account_age: 53
# total_trans: 1, total_fraud_trans: 0, account_age: 66
# total_trans: 1, total_fraud_trans: 0, account_age: 66
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 1, total_fraud_trans: 0, account_age: 112
# total_trans: 1, total_fraud_trans: 0, account_age: 56
# total_trans: 6, total_fraud_trans: 0, account_age: 94
# total_trans: 1, total_fraud_trans: 0, account_age: 69
# total_trans: 1, total_fraud_trans: 0, account_age: 46
# total_trans: 1, total_fraud_trans: 0, account_age: 35
# total_trans: 1, total_fraud_trans: 0, account_age: 39
# total_trans: 1, total_fraud_trans: 0, account_age: 44
# total_trans: 1, total_fraud_trans: 0, account_age: 108
# total_trans: 1, total_fraud_trans: 0, account_age: 118
# total_trans: 1, total_fraud_trans: 0, account_age: 86
# total_trans: 1, total_fraud_trans: 0, account_age: 97
# total_trans: 1, total_fraud_trans: 0, account_age: 87
# total_trans: 1, total_fraud_trans: 0, account_age: 40
# total_trans: 10, total_fraud_trans: 0, account_age: 45
# total_trans: 1, total_fraud_trans: 0, account_age: 99
# total_trans: 1, total_fraud_trans: 0, account_age: 104
# total_trans: 1, total_fraud_trans: 0, account_age: 24
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 59
# total_trans: 1, total_fraud_trans: 0, account_age: 39
# total_trans: 1, total_fraud_trans: 0, account_age: 39
# total_trans: 1, total_fraud_trans: 0, account_age: 58
# total_trans: 1, total_fraud_trans: 0, account_age: 47
# total_trans: 1, total_fraud_trans: 0, account_age: 74
# total_trans: 1, total_fraud_trans: 0, account_age: 112
# total_trans: 1, total_fraud_trans: 0, account_age: 35
# total_trans: 1, total_fraud_trans: 0, account_age: 112
# total_trans: 1, total_fraud_trans: 0, account_age: 101
# total_trans: 1, total_fraud_trans: 0, account_age: 60
# total_trans: 1, total_fraud_trans: 0, account_age: 61
# total_trans: 1, total_fraud_trans: 0, account_age: 26
# total_trans: 1, total_fraud_trans: 0, account_age: 79
# total_trans: 1, total_fraud_trans: 0, account_age: 113
# total_trans: 1, total_fraud_trans: 0, account_age: 103
# total_trans: 1, total_fraud_trans: 0, account_age: 59
# total_trans: 1, total_fraud_trans: 0, account_age: 90
# total_trans: 1, total_fraud_trans: 0, account_age: 48
# total_trans: 1, total_fraud_trans: 0, account_age: 56
# total_trans: 1, total_fraud_trans: 0, account_age: 44
# total_trans: 1, total_fraud_trans: 0, account_age: 110
# total_trans: 1, total_fraud_trans: 0, account_age: 108
# total_trans: 1, total_fraud_trans: 0, account_age: 38
# total_trans: 11, total_fraud_trans: 0, account_age: 71
# total_trans: 1, total_fraud_trans: 0, account_age: 50
# total_trans: 1, total_fraud_trans: 0, account_age: 112
# total_trans: 1, total_fraud_trans: 0, account_age: 95
# total_trans: 1, total_fraud_trans: 0, account_age: 25
# total_trans: 1, total_fraud_trans: 0, account_age: 102
# total_trans: 1, total_fraud_trans: 0, account_age: 111
# total_trans: 1, total_fraud_trans: 0, account_age: 117
# total_trans: 1, total_fraud_trans: 0, account_age: 21
# total_trans: 1, total_fraud_trans: 0, account_age: 109
# total_trans: 1, total_fraud_trans: 0, account_age: 76
# total_trans: 1, total_fraud_trans: 0, account_age: 89
# total_trans: 21, total_fraud_trans: 0, account_age: 31
# total_trans: 1, total_fraud_trans: 0, account_age: 43
# total_trans: 1, total_fraud_trans: 0, account_age: 114
# total_trans: 1, total_fraud_trans: 0, account_age: 97
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 28
# total_trans: 1, total_fraud_trans: 0, account_age: 84
# total_trans: 1, total_fraud_trans: 0, account_age: 45
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 74
# total_trans: 1, total_fraud_trans: 0, account_age: 58
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 1, total_fraud_trans: 0, account_age: 61
# total_trans: 1, total_fraud_trans: 0, account_age: 87
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 30
# total_trans: 1, total_fraud_trans: 0, account_age: 102
# total_trans: 1, total_fraud_trans: 0, account_age: 28
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 5, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 98
# total_trans: 1, total_fraud_trans: 0, account_age: 22
# total_trans: 1, total_fraud_trans: 0, account_age: 48
# total_trans: 1, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 59
# total_trans: 1, total_fraud_trans: 0, account_age: 21
# total_trans: 1, total_fraud_trans: 0, account_age: 78
# total_trans: 1, total_fraud_trans: 0, account_age: 79
# total_trans: 1, total_fraud_trans: 0, account_age: 94
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 68
# total_trans: 1, total_fraud_trans: 0, account_age: 29
# total_trans: 1, total_fraud_trans: 0, account_age: 107
# total_trans: 1, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 71
# total_trans: 1, total_fraud_trans: 0, account_age: 40
# total_trans: 1, total_fraud_trans: 0, account_age: 116
# total_trans: 1, total_fraud_trans: 0, account_age: 76
# total_trans: 1, total_fraud_trans: 0, account_age: 84
# total_trans: 1, total_fraud_trans: 0, account_age: 37
# total_trans: 1, total_fraud_trans: 0, account_age: 72
# total_trans: 1, total_fraud_trans: 0, account_age: 27
# total_trans: 1, total_fraud_trans: 0, account_age: 114
# total_trans: 1, total_fraud_trans: 0, account_age: 58
# total_trans: 1, total_fraud_trans: 0, account_age: 85
# total_trans: 1, total_fraud_trans: 0, account_age: 118
# total_trans: 1, total_fraud_trans: 0, account_age: 67
# total_trans: 1, total_fraud_trans: 0, account_age: 56
# total_trans: 1, total_fraud_trans: 0, account_age: 68
# total_trans: 1, total_fraud_trans: 0, account_age: 46
# total_trans: 1, total_fraud_trans: 0, account_age: 43
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 50
# total_trans: 1, total_fraud_trans: 0, account_age: 48
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 1, total_fraud_trans: 0, account_age: 104
# total_trans: 1, total_fraud_trans: 0, account_age: 113
# total_trans: 1, total_fraud_trans: 0, account_age: 74
# total_trans: 1, total_fraud_trans: 0, account_age: 92
# total_trans: 1, total_fraud_trans: 0, account_age: 68
# total_trans: 1, total_fraud_trans: 0, account_age: 26
# total_trans: 1, total_fraud_trans: 0, account_age: 110
# total_trans: 1, total_fraud_trans: 0, account_age: 73
# total_trans: 1, total_fraud_trans: 0, account_age: 93
# total_trans: 1, total_fraud_trans: 0, account_age: 77
# total_trans: 1, total_fraud_trans: 0, account_age: 48
# total_trans: 1, total_fraud_trans: 0, account_age: 85
# total_trans: 1, total_fraud_trans: 0, account_age: 51
# total_trans: 1, total_fraud_trans: 0, account_age: 68
# total_trans: 2, total_fraud_trans: 0, account_age: 106
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 64
# total_trans: 1, total_fraud_trans: 0, account_age: 99
# total_trans: 1, total_fraud_trans: 0, account_age: 119
# total_trans: 1, total_fraud_trans: 0, account_age: 25
# total_trans: 1, total_fraud_trans: 0, account_age: 90
# total_trans: 1, total_fraud_trans: 0, account_age: 71
# total_trans: 1, total_fraud_trans: 0, account_age: 72
# total_trans: 1, total_fraud_trans: 0, account_age: 38
# total_trans: 1, total_fraud_trans: 0, account_age: 63
# total_trans: 1, total_fraud_trans: 0, account_age: 109
# total_trans: 1, total_fraud_trans: 0, account_age: 102
# total_trans: 1, total_fraud_trans: 0, account_age: 68
# total_trans: 1, total_fraud_trans: 0, account_age: 21
# total_trans: 1, total_fraud_trans: 0, account_age: 30
# total_trans: 1, total_fraud_trans: 0, account_age: 116
# total_trans: 1, total_fraud_trans: 0, account_age: 95
# total_trans: 1, total_fraud_trans: 0, account_age: 55
# total_trans: 1, total_fraud_trans: 0, account_age: 74
# total_trans: 1, total_fraud_trans: 0, account_age: 48
# total_trans: 1, total_fraud_trans: 0, account_age: 85
# total_trans: 2, total_fraud_trans: 0, account_age: 68
# total_trans: 1, total_fraud_trans: 0, account_age: 95
# total_trans: 1, total_fraud_trans: 0, account_age: 53
# total_trans: 1, total_fraud_trans: 0, account_age: 39
# total_trans: 1, total_fraud_trans: 0, account_age: 107
# total_trans: 1, total_fraud_trans: 0, account_age: 97
# total_trans: 1, total_fraud_trans: 0, account_age: 81
# total_trans: 1, total_fraud_trans: 0, account_age: 38
# total_trans: 1, total_fraud_trans: 0, account_age: 24
# total_trans: 1, total_fraud_trans: 0, account_age: 25

# %%
import hopsworks

project = hopsworks.login()

fs = project.get_feature_store()
# Out:
# Copy your Api Key (first register/login): https://c.app.hopsworks.ai/account/api/generated
#
# Paste it here: ··········
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1213626

# %%
# Get or create the 'transactions' feature group
trans_fg = fs.get_or_create_feature_group(
    name="transactions",
    version=1,
    description="Transaction data",
    primary_key=["transaction_id"],
    event_time="date",
    online_enabled=True,
)

# %%
# Insert data into feature group
trans_fg.insert(data)
# Out:
# FeatureGroupWarning: The ingested dataframe contains upper case letters in feature names: `['nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud', 'isFlaggedFraud']`. Feature names are sanitized to lower case in the feature store.
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1213626/fs/1200267/fg/1400957
# Uploading Dataframe: 100.00% |██████████| Rows 6362620/6362620 | Elapsed Time: 09:15 | Remaining Time: 00:00
# Launching job: transactions_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1213626/jobs/named/transactions_1_offline_fg_materialization/executions
# (Job('transactions_1_offline_fg_materialization', 'SPARK'), None)

# %%
# Update feature descriptions
feature_descriptions = [
    {"name": "transaction_id", "description": "Transaction id"},
    {"name": "date", "description": "Transaction time"},
    {"name": "step", "description": "maps a unit of time in the real world. In this case 1 step is 1 hour of time. Total steps 744 (30 days simulation)."},
    {"name": "amount", "description": "amount of the transaction in local currency"},
    {"name": "nameorig", "description": "customer who started the transaction"},
    {"name": "oldbalanceorg", "description": "initial balance before the transaction"},
    {"name": "newbalanceorig", "description": "new balance after the transaction"},
    {"name": "namedest", "description": "customer who is the recipient of the transaction"},
    {"name": "oldbalancedest", "description": "initial balance recipient before the transaction. Note that there is not information for customers that start with M (Merchants)"},
    {"name": "newbalancedest", "description": "new balance recipient after the transaction. Note that there is not information for customers that start with M (Merchants)"},
    {"name": "isfraud", "description": "fraudulent behavior of the agents aims to profit by taking control or customers accounts and try to empty the funds by transferring to another account and then cashing out of the system"},
    {"name": "isflaggedfraud", "description": "An illegal attempt in this dataset is an attempt to transfer more than 200.000 in a single transaction"},
    {"name": "state", "description": "state where transaction happened"},
    {"name": "zipcode", "description": "zipcode where transaction happened"}
]

for desc in feature_descriptions:
    trans_fg.update_feature_description(desc["name"], desc["description"])

# %%
# Select features for training data
data_cols = ['transaction_id', 'step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
       'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
       'isFlaggedFraud', 'date']
selected_features = trans_fg.select(data_cols)
selected_features.show(5)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (53.73s)
#    transaction_id  step      type     amount     nameorig  oldbalanceorg  \
# 0         1050236    95   CASH_IN  327060.99   C277542917     9679606.12
# 1          487075    19  CASH_OUT   98056.68  C1739707237        8469.00
# 2         1925088   167   PAYMENT    3457.36  C1367949555        1052.00
# 3          423455    18   CASH_IN  113256.95   C826616230    11674912.08
# 4          455607    19  CASH_OUT  260417.16   C253927786       36519.00
#
#    newbalanceorig     namedest  oldbalancedest  newbalancedest  isfraud  \
# 0     10006667.11    C18058083       449422.09       122361.11        0
# 1            0.00  C1965963623       529722.54       627779.22        0
# 2            0.00   M194892973            0.00            0.00        0
# 3     11788169.03  C1010549417       517791.59       778301.47        0
# 4            0.00  C2008807592       680742.69       941159.85        0
#
#    isflaggedfraud                      date
# 0               0 2018-01-18 16:08:15+00:00
# 1               0 2018-01-15 12:08:15+00:00
# 2               0 2018-01-21 16:08:15+00:00
# 3               0 2018-01-15 11:08:15+00:00
# 4               0 2018-01-15 12:08:15+00:00

# %%
type(selected_features.s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-9e33f7784b34> in <cell line: 0>()
# ----> 1 type(selected_features.show())
#
# TypeError: Query.show() missing 1 required positional argument: 'n'
